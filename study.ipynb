# %%
# %run pylib/setup dark

df = pd.read_csv('files/var_info.csv', index_col=0)

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.scatter(data=df.query('nbb>2'), x='bb_var', y='variability', s=10, color='cyan', label='nbb>2')
ax.scatter(data=df.query('1<nbb<3'), x='bb_var', y='variability', s=10, color='red',label='nbb==2')
# ax.scatter(dfx.bb_var, dfx.variability, s=10, color='cyan')
ax.set(xscale='log', yscale='log', xlabel='BB variability', ylabel='DR4 Variability index',
title='Comparison of the variability measures.')
ax.legend();
